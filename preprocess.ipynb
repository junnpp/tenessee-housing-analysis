# %%
import pandas as pd

# %% [markdown]
# ## Motivation
#
#
# To visualize a city map in Tableau, the dataset must contain the zip code for each city. Here, I joined the `zipcodes` dataset that contains all the zip codes for each city in Tennessee and joined it on the `Housing` dataset
#
# - Zip Codes (Tennessee) : https://www.zip-codes.com/state/tn.asp

# %%
# import two datasets for joining
zipcodes = pd.read_csv("./data/Zipcodes.csv")
housing = pd.read_csv("./data/housing-cleaned.csv")

# %%
zipcodes.head(10)
# Out:
#    ZIP Code          City
# 0     37010         Adams
# 1     37011       Antioch
# 2     37012    Alexandria
# 3     37013       Antioch
# 4     37014     Arrington
# 5     37015  Ashland City
# 6     37016    Auburntown
# 7     37018    Beechgrove
# 8     37019       Belfast
# 9     37020   Bell Buckle

# %%
housing.head(5)
# Out:
#    UniqueID         ParcelID        LandUse    SaleDate  SalePrice  \
# 0      2045  007 00 0 125.00  SINGLE FAMILY  2013-04-09     240000
# 1     16918  007 00 0 130.00  SINGLE FAMILY  2014-06-10     366000
# 2     54582  007 00 0 138.00  SINGLE FAMILY  2016-09-26     435000
# 3     43070  007 00 0 143.00  SINGLE FAMILY  2016-01-29     255000
# 4     22714  007 00 0 149.00  SINGLE FAMILY  2014-10-10     278000
#
#      LegalReference SoldAsVacant                           OwnerName  Acreage  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE      2.3
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE      3.5
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE      2.9
# 3  20160129-0008913           No            BAKER, JAY K. & SUSAN E.      2.6
# 4  20141015-0095255           No  POST, CHRISTOPHER M. & SAMANTHA C.      2.0
#
#    LandValue  ...  TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath  \
# 0    50000.0  ...    235700.0     1986.0       3.0       3.0       0.0
# 1    50000.0  ...    319000.0     1998.0       3.0       3.0       2.0
# 2    50000.0  ...    298000.0     1987.0       4.0       3.0       0.0
# 3    50000.0  ...    197300.0     1985.0       3.0       3.0       0.0
# 4    50000.0  ...    202300.0     1984.0       4.0       3.0       0.0
#
#    PropertySplitAddress PropertySplitCity   OwnerSplitAddress  OwnerSplitCity  \
# 0    1808  FOX CHASE DR    GOODLETTSVILLE  1808  FOX CHASE DR  GOODLETTSVILLE
# 1    1832  FOX CHASE DR    GOODLETTSVILLE  1832  FOX CHASE DR  GOODLETTSVILLE
# 2    1864 FOX CHASE  DR    GOODLETTSVILLE  1864  FOX CHASE DR  GOODLETTSVILLE
# 3    1853  FOX CHASE DR    GOODLETTSVILLE  1853  FOX CHASE DR  GOODLETTSVILLE
# 4    1829  FOX CHASE DR    GOODLETTSVILLE  1829  FOX CHASE DR  GOODLETTSVILLE
#
#   OwnerSplitState
# 0              TN
# 1              TN
# 2              TN
# 3              TN
# 4              TN
#
# [5 rows x 21 columns]

# %%
# capitalize all city names in zipcodes dataset
zipcodes["City"] = zipcodes["City"].str.upper()
zipcodes.head(10)
# Out:
#    ZIP Code          City
# 0     37010         ADAMS
# 1     37011       ANTIOCH
# 2     37012    ALEXANDRIA
# 3     37013       ANTIOCH
# 4     37014     ARRINGTON
# 5     37015  ASHLAND CITY
# 6     37016    AUBURNTOWN
# 7     37018    BEECHGROVE
# 8     37019       BELFAST
# 9     37020   BELL BUCKLE

# %%
# join two datasets
df = housing.merge(zipcodes, left_on='PropertySplitCity', right_on="City", how='left')

# %%
df.head()
# Out:
#    UniqueID         ParcelID        LandUse    SaleDate  SalePrice  \
# 0      2045  007 00 0 125.00  SINGLE FAMILY  2013-04-09     240000
# 1      2045  007 00 0 125.00  SINGLE FAMILY  2013-04-09     240000
# 2     16918  007 00 0 130.00  SINGLE FAMILY  2014-06-10     366000
# 3     16918  007 00 0 130.00  SINGLE FAMILY  2014-06-10     366000
# 4     54582  007 00 0 138.00  SINGLE FAMILY  2016-09-26     435000
#
#      LegalReference SoldAsVacant                  OwnerName  Acreage  \
# 0  20130412-0036474           No  FRAZIER, CYRENTHA LYNETTE      2.3
# 1  20130412-0036474           No  FRAZIER, CYRENTHA LYNETTE      2.3
# 2  20140619-0053768           No    BONER, CHARLES & LESLIE      3.5
# 3  20140619-0053768           No    BONER, CHARLES & LESLIE      3.5
# 4  20160927-0101718           No  WILSON, JAMES E. & JOANNE      2.9
#
#    LandValue  ...  Bedrooms  FullBath  HalfBath  PropertySplitAddress  \
# 0    50000.0  ...       3.0       3.0       0.0    1808  FOX CHASE DR
# 1    50000.0  ...       3.0       3.0       0.0    1808  FOX CHASE DR
# 2    50000.0  ...       3.0       3.0       2.0    1832  FOX CHASE DR
# 3    50000.0  ...       3.0       3.0       2.0    1832  FOX CHASE DR
# 4    50000.0  ...       4.0       3.0       0.0    1864 FOX CHASE  DR
#
#    PropertySplitCity   OwnerSplitAddress  OwnerSplitCity OwnerSplitState  \
# 0     GOODLETTSVILLE  1808  FOX CHASE DR  GOODLETTSVILLE              TN
# 1     GOODLETTSVILLE  1808  FOX CHASE DR  GOODLETTSVILLE              TN
# 2     GOODLETTSVILLE  1832  FOX CHASE DR  GOODLETTSVILLE              TN
# 3     GOODLETTSVILLE  1832  FOX CHASE DR  GOODLETTSVILLE              TN
# 4     GOODLETTSVILLE  1864  FOX CHASE DR  GOODLETTSVILLE              TN
#
#   ZIP Code            City
# 0  37070.0  GOODLETTSVILLE
# 1  37072.0  GOODLETTSVILLE
# 2  37070.0  GOODLETTSVILLE
# 3  37072.0  GOODLETTSVILLE
# 4  37070.0  GOODLETTSVILLE
#
# [5 rows x 23 columns]

# %%
# export the dataset
df.to_csv("housing-with-zipcode.csv")
